# %% [markdown]
# # PLAID

# %%
# plot

# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

def plot_qps_metrics(csv_file, topk=None, ndocs_list=None):
    """
    PLAID
    绘制 QPS vs Recall@100 和 QPS vs MRR@100 曲线。
    
    参数:
        csv_file (str): CSV 文件路径。
        topk (int, optional): 只绘制指定 topk 的结果（如 100）。
        ndocs_list (list, optional): 只绘制 retrieval_ndocs 在列表中的行。
    """
    # 读取数据
    df = pd.read_csv(csv_file)

    # 过滤 topk
    if topk is not None:
        df = df[df['topk'] == topk]
    
    # 过滤 ndocs
    if ndocs_list is not None:
        df = df[df['retrieval_ndocs'].isin(ndocs_list)]
    
    # 如果过滤后为空，给出提示
    if df.empty:
        print("筛选后没有数据，请检查参数。")
        return
    
    # 按 QPS 升序排序，使曲线连贯
    df_sorted = df.sort_values("qps")
    
    # 设置绘图风格
    plt.style.use('seaborn-v0_8-whitegrid')
    plt.rcParams['font.size'] = 12
    
    # 创建两个子图，方便比较
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
    
    # ---------- 图1: QPS vs Recall@100 ----------
    ax1.plot(df_sorted["qps"], df_sorted["recall@100"], 
             marker='o', linestyle='-', linewidth=2, markersize=8, color='b')
    ax1.set_xlabel("QPS (queries/sec)", fontsize=14)
    ax1.set_ylabel("Recall@100", fontsize=14)
    ax1.set_title("QPS vs Recall@100", fontsize=16)
    ax1.grid(True, linestyle='--', alpha=0.7)
    
    # 标注每个点：优先使用 'retrieval_ndocs' 列，若无则用行号
    if 'retrieval_ndocs' in df_sorted.columns:
        label_col = 'retrieval_ndocs'
        label_prefix = 'ndocs='
    else:
        label_col = None
        label_prefix = ''
    
    for idx, row in df_sorted.iterrows():
        if label_col:
            label = f"{label_prefix}{row[label_col]}"
        else:
            label = f"idx{idx}"
        ax1.annotate(label, 
                     xy=(row["qps"], row["recall@100"]),
                     xytext=(5, 5), textcoords='offset points', fontsize=9)
    
    # ---------- 图2: QPS vs MRR@100 ----------
    ax2.plot(df_sorted["qps"], df_sorted["mrr@100"], 
             marker='s', linestyle='-', linewidth=2, markersize=8, color='r')
    ax2.set_xlabel("QPS (queries/sec)", fontsize=14)
    ax2.set_ylabel("MRR@100", fontsize=14)
    ax2.set_title("QPS vs MRR@100", fontsize=16)
    ax2.grid(True, linestyle='--', alpha=0.7)
    
    for idx, row in df_sorted.iterrows():
        if label_col:
            label = f"{label_prefix}{row[label_col]}"
        else:
            label = f"idx{idx}"
        ax2.annotate(label, 
                     xy=(row["qps"], row["mrr@100"]),
                     xytext=(5, 5), textcoords='offset points', fontsize=9)

    ax1.set_xscale('log')
    ax2.set_xscale('log')
    ax1.set_xticks([1, 10, 100, 1000])
    ax1.set_xticklabels(['$10^0$', '$10^1$', '$10^2$', '$10^3$'])
    ax2.set_xticks([1, 10, 100, 1000])
    ax2.set_xticklabels(['$10^0$', '$10^1$', '$10^2$', '$10^3$'])
    
    plt.tight_layout()
    
    # 保存到 CSV 同目录，文件名与 CSV 相同（扩展名 .png）
    output_dir = os.path.dirname(csv_file)
    base_name = os.path.splitext(os.path.basename(csv_file))[0]
    save_path = os.path.join(output_dir, base_name + ".png")
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f"图片已保存为 '{save_path}'")

# [10,50,100,200,500,1000,2000,5000,8000,10000]

# %% [markdown]
# ## Scidocs-large(1024 dim)

# %%
# Prepare a flat dataset

python script/flat_multivector/prepare_flat_multivector_dataset.py \
    --username chenyifeng \
    --dataset scidocs-large-multi-flat-test \
    --doc-embeddings /data1/chenyifeng/Data_backup/scidocs-large-multi/full_multi_embeddings_scidocs-large.npy \
    --doc-lens /data1/chenyifeng/Data_backup/scidocs-large-multi/full_multi_chunk_num_scidocs-large.npy \
    --query-embeddings /data1/chenyifeng/Data_backup/scidocs-large-multi/full_multi_embeddings_scidocs-large_query.npy \
    --query-lens /data1/chenyifeng/Data_backup/scidocs-large-multi/full_multi_chunk_num_scidocs-large_query.npy \
    --max-queries 1000 \
    --force


--qrels-tsv /data1/chenyifeng/Data_backup/scidocs/beir/qrels/test.tsv \
# !!! gt file

# %%
# Build the Plaid index

export CUDA_VISIBLE_DEVICES=3
export CXX=/usr/bin/g++-9
export CC=/usr/bin/gcc-9

python script/flat_multivector/build_plaid_from_flat_dataset.py \
    --username chenyifeng \
    --dataset scidocs-large-multi-flat-test \
    --manifest /data1/chenyifeng/Dataset/multi-vector-retrieval/FlatData/scidocs-large-multi-flat-test/manifest.json

# %% [markdown]
# then can run dessert reterival

# %%
# Run Plaid retrieval

python script/evaluation/eval_plaid.py \
    --username chenyifeng \
    --dataset scidocs-large-multi-flat-test

# %%
# Evaluate Plaid results against local ground truth

python script/flat_multivector/eval_flat_groundtruth.py \
    --username chenyifeng \
    --dataset scidocs-large-multi-flat-test \
    --method plaid

# %%
# plot

plot_qps_metrics("/path/to/your/new_file.csv")

# %% [markdown]
# ## Scidocs

# %%
# Prepare a flat dataset

python script/flat_multivector/prepare_flat_multivector_dataset.py \
    --username chenyifeng \
    --dataset scidocs \
    --doc-embeddings /data1/chenyifeng/Data_backup/scidocs/colbert/corpus_points.npy \
    --doc-lens /data1/chenyifeng/Data_backup/scidocs/colbert/doclens.npy \
    --query-embeddings /data1/chenyifeng/Data_backup/scidocs/colbert/query_points.npy \
    --query-lens /data1/chenyifeng/Data_backup/scidocs/colbert/query_doclens.npy \
    --qrels-tsv /data1/chenyifeng/Data_backup/scidocs/beir/qrels/test.tsv \
    --corpus-ids-json /data1/chenyifeng/Data_backup/scidocs/colbert/corpus_ids.json \
    --query-ids-json /data1/chenyifeng/Data_backup/scidocs/colbert/query_ids.json \
    --max-queries 1000 \
    --force


--qrels-tsv /data1/chenyifeng/Data_backup/scidocs/beir/qrels/test.tsv \
--corpus-ids-json /data/ali/scidocs-modern-colbert/corpus_ids.json \
--query-ids-json /data/ali/scidocs-modern-colbert/query_ids.json \
# !!! gt file

# %%
# Run one wrapper

bash script/flat_multivector/run_plaid_flat.sh chenyifeng scidocs
# Out:
#   Cell In[4], line 3
#     bash script/flat_multivector/run_plaid_flat.sh chenyifeng scidocs
#          ^
# SyntaxError: invalid syntax

# %%
# plot

plot_qps_metrics("/data1/chenyifeng/Dataset/multi-vector-retrieval/Result/performance/plaid-scidocs-flat-eval-summary.csv",
                 topk=100,
                 ndocs_list=[50,200,500,1000,2000,5000,8000,10000])
# Out:
# 图片已保存为 '/data1/chenyifeng/Dataset/multi-vector-retrieval/Result/performance/plaid-scidocs-flat-eval-summary.png'

# %% [markdown]
# ## Fiqa

# %%
# Prepare a flat dataset

python script/flat_multivector/prepare_flat_multivector_dataset.py \
    --username chenyifeng \
    --dataset fiqa \
    --doc-embeddings /data1/chenyifeng/Data_backup/fiqa/colbert/corpus_points.npy \
    --doc-lens /data1/chenyifeng/Data_backup/fiqa/colbert/doclens.npy \
    --query-embeddings /data1/chenyifeng/Data_backup/fiqa/colbert/query_points.npy \
    --query-lens /data1/chenyifeng/Data_backup/fiqa/colbert/query_doclens.npy \
    --qrels-tsv /data1/chenyifeng/Data_backup/fiqa/beir/qrels/test.tsv \
    --corpus-ids-json /data1/chenyifeng/Data_backup/fiqa/colbert/corpus_ids.json \
    --query-ids-json /data1/chenyifeng/Data_backup/fiqa/colbert/query_ids.json \
    --max-queries 648 \
    --force

--max-queries 1000 \
--qrels-tsv /data1/chenyifeng/Data_backup/scidocs/beir/qrels/test.tsv \
--corpus-ids-json /data/ali/scidocs-modern-colbert/corpus_ids.json \
--query-ids-json /data/ali/scidocs-modern-colbert/query_ids.json \
# !!! gt file

# %%
# Run one wrapper

bash script/flat_multivector/run_plaid_flat.sh chenyifeng fiqa

# %%
# plot

plot_qps_metrics("/data1/chenyifeng/Dataset/multi-vector-retrieval/Result/performance/plaid-scidocs-flat-eval-summary.csv",
                 topk=100,
                 ndocs_list=[50,200,500,1000,2000,5000,8000,10000])
# Out:
# 图片已保存为 '/data1/chenyifeng/Dataset/multi-vector-retrieval/Result/performance/plaid-scidocs-flat-eval-summary.png'
