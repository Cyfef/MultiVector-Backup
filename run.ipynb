# %% [markdown]
# # MultiVector Baselines
#
# ---

# %% [markdown]
# ### Data Format: flat multi-vector
#
#
# - Run guide: /data1/chenyifeng/mvr_index/mvr-baselines/README_flat_multivector.md
# - small dataset test for environment and code: result--/data1/chenyifeng/mvr_index/mvr-baselines/results/flat_validation/scidocs-large-multi-flat-test/scidocs-large-multi-flat-test-flat-eval-summary.csv
#
# ---
#
# - pipeline/framework for test
# - 2D data format

# %% [markdown]
# ## Dataset and Benchmark: BEIR
#
# - zero-shot evaluation benchmark
# - 18 public dataset + 9 IR task: all datasets follow a structure
# - evaluate 10 reterival system
#
# ---

# %% [markdown]
# ### Algorithm1: Plaid
#
# - Colbert: generate embedding vector + MaxSim scoring algorithm
# - Plaid: build index + search via index
# - same authors
#
# ---
#
# - algorithm code:
#     1. MultiVector-Backup/multivector_baselines/baseline/ColBERT/colbert/indexer.py
#     2. MultiVector-Backup/multivector_baselines/baseline/ColBERT/colbert/searcher.py

# %% [markdown]
# ### Algorithm2: Dessert
#
# - based on index built by plaid: centroids + centroid_id
# - build index and search
#
# ---
#
# - algorithm code: MultiVector-Backup/multivector_baselines/baseline/Dessert/experiments/run_dessert.py

# %% [markdown]
# ### Algorithm3: EMVB
#
# - performance evaluation tool: perf_emvb
# - python: index,eval + cpp: search
#
# ---
#
# - algorithm code:
#     1. MultiVector-Backup/EMVB/include
#     2. MultiVector-Backup/EMVB/src/perf_emvb.cpp

# %% [markdown]
# ### Algorithm4: WARP
#
# ---
#
# - algorithm code:
#     1. MultiVector-Backup/WARP/utility/index_from_embeddings.py
#     2.

# %% [markdown]
# ### Algorithm5: MUVERA

# %% [markdown]
# ### Algorithm6: IGP

# %% [markdown]
# ### Algorithm7: GEM
#
# - /data1/chenyifeng/mvr_index/gem
#
# - hnswlib/: source needed to build example_vecset_search_gem.
# - scripts/: preprocessing, run, and evaluation scripts.
# - results/scidocs_verification/: SciDocs verification TSVs, metadata, logs, run config, saved eval CSV, and recomputed eval CSV.
#
# - build: /data1/lijunlin/mvr_index/gem/hnswlib/build/example_vecset_search_gem
# - Recomputed SciDocs evaluation:
#
#   common_queries = 1000
#   missing qrel query ids = 0
#   missing qrel doc ids = 0
# - Key verification output:
#
#   rerank1024 ef4000: MRR@10=0.274601, NDCG@10=0.152603, Recall@100=0.350333
#   rerank512  ef4000: MRR@10=0.273856, NDCG@10=0.151965, Recall@100=0.344233

# %% [markdown]
# ### Algorithm8: XTR

# %%
export ALL_PROXY=socks5://127.0.0.1:7891
export HTTP_PROXY=socks5://127.0.0.1:7891
export HTTPS_PROXY=socks5://127.0.0.1:7891

# %%
export TRANSFORMERS_CACHE=/data1/chenyifeng/tmp/hf-cache
export HF_HOME=/data1/chenyifeng/tmp/hf-cache

# %%
export PYTHONHTTPSVERIFY=0
export HF_HUB_DISABLE_SSL_VERIFY=1   # 如果 huggingface_hub 支持
export CURL_CA_BUNDLE=""
export REQUESTS_CA_BUNDLE=""

# %%
import os

os.environ['HF_ENDPOINT'] = 'https://hf-mirror.com'   # 使用镜像
# 确保不设置任何代理环境变量
os.environ.pop('HTTP_PROXY', None)
os.environ.pop('HTTPS_PROXY', None)
os.environ.pop('ALL_PROXY', None)

from huggingface_hub import snapshot_download

save_dir = "/data1/chenyifeng/MultiVector-Backup/dpr-scale/model"
repo_id = "google-bert/bert-base-uncased"

snapshot_download(
  local_dir=save_dir,
  repo_id=repo_id,
  local_dir_use_symlinks=False,
  allow_patterns=[],
)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /data1/chenyifeng/miniconda3/envs/flatmulti/lib/python3.10/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File /data1/chenyifeng/miniconda3/envs/flatmulti/lib/python3.10/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...
